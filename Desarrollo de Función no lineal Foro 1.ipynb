# %% [markdown]
# # <center> Universidad de las Fuerzas Armadas</center>
#   # <center> Métodos Numéricos</center>
#    ## FORO.-1 SEGUNDA PARTICIPACIÓN
#    ## --------------------------------------------------------------------------------------------------------------------------------
#    ### Apellidos: **Pallo Yautibug**
#    ### Nombres: **Roberto Carlos**
#    ### NRC:_3657_
#    ## -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# A continuación voy a realizar el ejercicio propuesto por la compañera -***Naranjo Valery***- donde tenemos la siguiente ecuación:
# $f(x)=3cos^2(x)-cos(3x)$

# %%
#Importamos las librerias necesarias para graficar funciones como matplotlib y numpy
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# Graficas dinamicas 
# %matplotlib notebook

# %%
#Creación de un sistema lineal  o eje de coordenadas
#Definición de la función
x=np.linspace(-5,8,150)
def f(x):
    return 3*np.cos(x)*np.cos(x)-np.cos(3*x)

# %%
#Creación del Plano Cartesiano
fig, ax = plt.subplots()
#Definición de ejes en el plano cartesiano
#Representación de las funciones f(x) y g(x) en el plano cartesiano
ax.plot(x,f(x))
xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()
ax.grid(True, linestyle='-')
ax.annotate("",xy=(xmax,0), xytext=(xmin,0),
            arrowprops=dict(color = 'black', width=1,headwidth=5,headlength=10))
ax.annotate("",xy=(0,ymax), xytext=(0,ymin),
            arrowprops=dict(color = 'black', width=1,headwidth=5,headlength=10))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ###  **METODO DE LA BISECCION**

# %%
import matplotlib.pyplot as plt
import numpy as np
#Definimos la funcion
def f(x):
    return 3*np.cos(x)*np.cos(x)-np.cos(3*x)
  
#Definir la funcion para la biseccion 
def bisec(a,b,tol):
 
    if (f(a) * f(b) >= 0):
        print("No existe raiz en el rango ",a,",",b,"\n")
        return
    c = a
    i = 0
    n = 12
   
    while (abs(b-a) > tol):
        i=i+1
        #Se suma y divide para 2 los extremos del intervalo hast encontrar la raiz
        c = (a+b)/2
        # Comprobamos si el punto medio es la raíz 
        if (f(c) == 0.0):
            break
        # decidimos en cual intervalo continuamos con los pasos anteriores
        if (f(c)*f(a) < 0):
            b = c
        else:
            a = c         
    print("En la interración : ",i,"se encuentra aproximadamente la raiz en el intervalo",a,",",b)
       
    print("El valor de la raiz es : ",c)

# %%
# Inicializando Datos de intervalos y tolerancia
a = 0
b = 2
tol = 0.000001
bisec(a, b, tol)
# Out:
# En la interración :  21 se encuentra aproximadamente la raiz en el intervalo 1.570796012878418 , 1.5707969665527344
# El valor de la raiz es :  1.570796012878418

# %% [markdown]
# ###  **METODO DE LA SECANTE **

# %%
import matplotlib.pyplot as plt
import numpy as np
#Definimos la funcion
def f(x):
    return x**4-x-8
#Definir la funcion para la secante  
def secante(a, b, tol):
    n = 0
    xm = 0
    x0 = 0
    c = 0
    if (f(a) * f(b) < 0):
        while True:
             
            # Calculamos el valor medio del intervalo
            x0 = ((a * f(b) - b * f(a)) /(f(b) - f(a)));
 
            # Comprobamos si x0 en la raiz buscada
            c = f(a) * f(x0);
 
            # Actualiza el valor de los intervalos
            a = b;
            b = x0;
 
            # Actualiza en uno el numero de interacciones
            n += 1;
 
            # Si x0 es raiz de la ecuación en el intervalo dado
            if (c == 0):
            # si x0 es la raiz detenemos el bucle
                break;
            xm = ((a * f(b) - b * f(a)) /(f(b) - f(a)));
             
            if(abs(xm - x0) < tol):
                break;
         
        print("Raiz de la función =",round(x0, 15));
        print("No. de interacciones= ", n);
         
    else:
        print("No posee raiz en el intervalo");

# %%
# Inicialización de datos como extremos del intervalo y tolerancia 
x1 = 10;
x2 = 20;
tol = 0.000001;
secante(x1, x2, tol);
# Out:
# No posee raiz en el intervalo

# %% [markdown]
# ### ***Análisis del Problema***

# %% [markdown]
# En el Método de Bisección se puede ver que recien a las 21 interracciones se llega a establecer una raiz aproximada con una tolerancia menor al $tolerancia = 0.000001$.Por otro lado con el Método de la Secante se logro un resultado mucho mas rápido en apenas 6 interacciones, utilizando el mismo nivel de erros en la tolerancia.

# %% [markdown]
# ### ***Conclusión***

# %% [markdown]
# Si podemos tomar como valor real el punto $1.570796326794896$ **"obtenido del graficador grafico Symbolab"** y obtenemos los errores absolutos para ambos métodos utilizados obtenemos los siguientes resultados:

# %%
import matplotlib.pyplot as plt
import numpy as np
b=1.570796012878418
s=1.570796343608094
r=1.570796326794896
eB=0.0
eS=0.0
#ERROR ABSOLUTO METODO BISECCION
eB=abs(r - b)
#ERROR ABSOLUTO METODO BISECCION
eS=abs(r - s)
print("El error absoluto por el método de la bisección es",eB)
print("El error absoluto por el método de la secante es",eS)
# Out:
# El error absoluto por el método de la bisección es 3.1391647792311517e-07
# El error absoluto por el método de la secante es 1.6813198167042742e-08

# %% [markdown]
# El error absoluto por el método de la bisección es
# ### 3.1391647792311517e-07
# El error absoluto por el método de la bisección es
# ### 1.6813198167042742e-08

# %% [markdown]
# Podemos notar de esta manera que aunque los resultados de ambos metodos son muy parecidos, el de menor margen de error el el método de la secante.Es decir es más preciso que el de la bisección.
